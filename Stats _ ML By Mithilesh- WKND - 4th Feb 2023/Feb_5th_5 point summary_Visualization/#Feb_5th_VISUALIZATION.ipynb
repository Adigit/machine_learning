# %%
# Feb_5_Visualization

# %%
# import basic libraries
import numpy as np# linear algebra
import pandas as pd# data processing, dataframe
import matplotlib.pyplot as plt# plotting the graph
# %matplotlib inline 
# best fit of image inside the notebook
import seaborn as sns# plotting the graph
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\Batch Dec12th Stats ML\\Dec_14th visualization_continue'

# %%
data=pd.read_csv("HR_Employee_Attrition_Data1.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
empdf=data.copy()

# %%
empdf.head()# first five rows info
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
empdf.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # count plot

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="Gender",data=empdf)
plt.title("Distribution of gender")
# Out:
# Text(0.5, 1.0, 'Distribution of gender')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="BusinessTravel",data=empdf)
plt.title("Distribution of business travel")
# Out:
# Text(0.5, 1.0, 'Distribution of business travel')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="Department",data=empdf)
plt.title("Distribution of Department")
# Out:
# Text(0.5, 1.0, 'Distribution of Department')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="JobRole",data=empdf,hue="Gender")
plt.title("Distribution of JobType")
# Out:
# Text(0.5, 1.0, 'Distribution of JobType')

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="Department",data=empdf,hue="Attrition")
plt.title("Distribution of Department")
# Out:
# Text(0.5, 1.0, 'Distribution of Department')

# %%
# factorplot
sns.factorplot(x="MaritalStatus",kind="count",data=empdf,hue="Attrition")

# %% [markdown]
# # BARPLOT

# %%
plt.figure(figsize=(7,4))
sns.barplot(x="Department",y="MonthlyRate",data=empdf,hue="Attrition")
plt.title("Distribution of Department")
# Out:
# Text(0.5, 1.0, 'Distribution of Department')

# %%
plt.figure(figsize=(7,4))
sns.barplot(x="Department",y="Age",data=empdf,hue="Gender")
plt.title("Distribution of Department")
# Out:
# Text(0.5, 1.0, 'Distribution of Department')

# %%
plt.figure(figsize=(7,4))
ax=sns.barplot(x="JobSatisfaction",y="JobRole",data=empdf,hue="Gender")
ax.set(ylabel="JobRole")
plt.xlabel("JobSatisfaction",fontsize=20)
plt.title("Distribution of JobSatisfaction")
# Out:
# Text(0.5, 1.0, 'Distribution of JobSatisfaction')

# %% [markdown]
# # histogram

# %%
plt.figure(figsize=(7,4))
ax=sns.histplot(x="JobSatisfaction",y="JobRole",data=empdf,hue="Gender")
ax.set(ylabel="JobRole")
plt.xlabel("JobSatisfaction",fontsize=20)
plt.title("Distribution of JobSatisfaction")
# Out:
# Text(0.5, 1.0, 'Distribution of JobSatisfaction')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="JobRole",data=empdf,hue="Gender")
plt.title("Distribution of JobSatisfaction")
# Out:
# Text(0.5, 1.0, 'Distribution of JobSatisfaction')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="MonthlyIncome",data=empdf,bins=10,kde=True)
plt.title("Distribution of Monthly")
# Out:
# Text(0.5, 1.0, 'Distribution of Monthly')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="Age",data=empdf,bins=10,kde=True)
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="Age",data=empdf,bins=10,kde=True,hue="Department")
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="MonthlyIncome",data=empdf,bins=10,kde=True,hue="Department")
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="MonthlyIncome",data=empdf,bins=10,kde=True,hue="Department",stat='probability' )
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %%
plt.figure(figsize=(15,8))
ax=sns.histplot(x="Age",data=empdf,bins=10,kde=True,hue="Department",stat="density")
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %% [markdown]
# # scatter plot

# %%
sns.scatterplot(
    data=empdf, 
    x='MonthlyIncome', y='HourlyRate', 
    hue="Attrition",
    palette='Paired_r'
    )
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='HourlyRate'>

# %% [markdown]
# # lineplot

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x="Age",data=empdf,y="Department")
plt.title("Distribution of AGE")
# Out:
# Text(0.5, 1.0, 'Distribution of AGE')

# %% [markdown]
# # pieplot

# %%
empdf["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.pie(x=empdf["Attrition"].value_counts(),labels=empdf["Attrition"].value_counts().index,autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x18ac2188220>,
# ...
#  [Text(-0.9618916732177651, 0.5336332157899547, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')],
#  [Text(-0.5246681853915082, 0.29107266315815705, '83.88%'),
#   Text(0.5246681853915082, -0.2910726631581571, '16.12%')])

# %%
plt.figure(figsize=(15,8))
plt.pie(x=empdf["Gender"].value_counts(),labels=empdf["Gender"].value_counts().index,autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x18ac21d36d0>,
# ...
#  [Text(-0.33991877217145816, 1.046162142464278, 'Male'),
#   Text(0.3399188701202255, -1.0461621106387813, 'Female')],
#  [Text(-0.18541023936624987, 0.5706338958896061, '60.00%'),
#   Text(0.18541029279285026, -0.5706338785302443, '40.00%')])

# %%
plt.figure(figsize=(15,8))
plt.pie(x=empdf["Department"].value_counts(),labels=empdf["Department"].value_counts().index,autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x18ac221bb80>,
# ...
#  [Text(-0.5108751650946098, 0.9741696801325502, 'Research & Development'),
#   Text(0.37548555701288383, -1.0339296864268501, 'Sales'),
#   Text(1.0900447132085396, -0.1476567750091844, 'Human Resources')],
#  [Text(-0.27865918096069625, 0.5313652800723001, '65.37%'),
#   Text(0.20481030382520934, -0.5639616471419181, '30.34%'),
#   Text(0.5945698435682942, -0.08054005909591874, '4.29%')])

# %%
plt.figure(figsize=(15,8))
setexplode = [0.1, 0, 0]
plt.pie(x=empdf["Department"].value_counts(),labels=empdf["Department"].value_counts().index,autopct="%0.2f%%",explode=setexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x18ac4a352b0>,
# ...
#  [Text(-0.5573183619213926, 1.0627305601446002, 'Research & Development'),
#   Text(0.37548555701288383, -1.0339296864268501, 'Sales'),
#   Text(1.0900447132085396, -0.1476567750091844, 'Human Resources')],
#  [Text(-0.32510237778747897, 0.6199261600843501, '65.37%'),
#   Text(0.20481030382520934, -0.5639616471419181, '30.34%'),
#   Text(0.5945698435682942, -0.08054005909591874, '4.29%')])

# %% [markdown]
# # setting explode

# %%
plt.figure(figsize=(15,8))
setexplode = [0.05, 0, 0,0.1,0,0.1]
plt.pie(x=empdf["EducationField"].value_counts(),labels=empdf["EducationField"].value_counts().index,autopct="%0.2f%%",explode=setexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x18ac4b3d5e0>,
# ...
#  [Text(0.3130434959419761, 1.1065729843297396, 'Life Sciences'),
#   Text(-0.9951095091219136, -0.4687825347164123, 'Medical'),
#   Text(0.2194966396897843, -1.0778781123878958, 'Marketing'),
#   Text(0.8796622061668735, -0.816207328466015, 'Technical Degree'),
#   Text(1.05386333339301, -0.315233365191208, 'Other'),
#   Text(1.198002788644091, -0.06920490156760456, 'Human Resources')],
#  [Text(0.17693762814111694, 0.6254542954907224, '41.22%'),
#   Text(-0.5427870049755892, -0.2556995643907703, '31.56%'),
#   Text(0.11972543983079142, -0.5879335158479431, '10.82%'),
#   Text(0.5131362869306761, -0.4761209416051753, '8.98%'),
#   Text(0.5748345454870963, -0.17194547192247708, '5.58%'),
#   Text(0.6988349600423862, -0.04036952591443599, '1.84%')])

# %% [markdown]
# # BOXPLOT

# %%
# BOXPLOT
plt.figure(figsize=(15,8))
sns.boxplot(data=empdf)
# Out:
# <AxesSubplot:>

# %%
# BOXPLOT
plt.figure(figsize=(15,8))
sns.boxplot(empdf["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# BOXPLOT
plt.figure(figsize=(15,8))
sns.boxplot(empdf["TotalWorkingYears"])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %%
# BOXPLOT
plt.figure(figsize=(15,8))
sns.boxplot(x="TotalWorkingYears", data=empdf)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %% [markdown]
# # Violin plot

# %%
# Violin plot
plt.figure(figsize=(15,8))
sns.violinplot(x=empdf["TotalWorkingYears"],y=empdf["Age"])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Age'>
